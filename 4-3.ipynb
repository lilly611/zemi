# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/workspaces/studypython/src/ゼミ/data/kyphosis.csv")
df
# Out:
#     kyphosis  age
# 0          0   71
# 1          0  158
# 2          1  128
# 3          0    2
# 4          0    1
# ..       ...  ...
# 78         1  157
# 79         0   26
# 80         0  120
# 81         1   42
# 82         0   36
#
# [83 rows x 2 columns]

# %%
df.plot(x="age", y="kyphosis")
# Out:
# <Axes: xlabel='age'>
